# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
age = [36, 25, 38, 46, 55, 68, 72, 55, 36, 38, 67, 45, 22, 48, 91, 46, 52, 61, 58, 55]

# %%
hist = plt.hist(age, edgecolor='b')
plt.show()
print(hist)
# Out:
# (array([2., 0., 4., 4., 4., 2., 2., 1., 0., 1.]), array([22. , 28.9, 35.8, 42.7, 49.6, 56.5, 63.4, 70.3, 77.2, 84.1, 91. ]), <BarContainer object of 10 artists>)

# %%
hist = plt.hist(age, color = 'y', edgecolor='r',density=True)

dens,bins,patch = hist

print(bins)

print(dens)

print(patch[0])
# Out:
# [22.  28.9 35.8 42.7 49.6 56.5 63.4 70.3 77.2 84.1 91. ]
# [0.01449275 0.         0.02898551 0.02898551 0.02898551 0.01449275
#  0.01449275 0.00724638 0.         0.00724638]
# Rectangle(xy=(22, 0), width=6.9, height=0.0144928, angle=0)

# %%
plt.hist(age, color = 'r', histtype='step')
plt.show()

# %%
age = [36, 25, 38, 46, 55, 68, 72, 55, 36, 38, 67, 45, 22, 48, 70, 46, 52, 61, 58, 55]

# %%
green_diamond=dict(markerfacecolor='g',marker='D')

# %%
green_diamond=dict(markerfacecolor='g',marker='D')

# %%
X1 = np.random.normal(0, 1, 500)
X2 = np.random.normal(0.3, 1, 500)

# %%
df = pd.DataFrame(index=['Atiya', 'Abbas', 'Cornelia', 'Stephanie', 'Monte','Paris'], 
                  data={'Apples':[20, 10, 40, 15, 50,120],
                        'Oranges':[35, 40, 25, 19, 33,50]})
df.describe()
# Out:
#            Apples    Oranges
# count    6.000000   6.000000
# mean    42.500000  33.666667
# std     40.957295  10.948364
# min     10.000000  19.000000
# 25%     16.250000  27.000000
# 50%     30.000000  34.000000
# 75%     47.500000  38.750000
# max    120.000000  50.000000

# %%
age_df = pd.DataFrame(age)
plt.boxplot(age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7f28ee7e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7f28e6d8d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7f28ee72d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7f28e3ad50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7f28e3a390>],
#  'means': []}

# %%
age_df.describe()
# Out:
#                0
# count  20.000000
# mean   49.650000
# std    14.342704
# min    22.000000
# 25%    38.000000
# 50%    50.000000
# 75%    58.750000
# max    72.000000
