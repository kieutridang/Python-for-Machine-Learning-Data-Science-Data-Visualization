# %%
import matplotlib.pyplot as plt

# %%
gdp_cap = [974, 5937, 6223, 4797, 12779]
life_exp = [43.8, 76.4, 72.3, 42.7, 75.3]

# %%
plt.scatter(gdp_cap, life_exp)
plt.show()

# %%
plt.scatter(gdp_cap, life_exp)

plt.show()

# %%
import numpy as np
N = 20
x = np.random.rand(N)
y = np.random.rand(N) 
z = np.random.rand(N) # color
area = (30 * np.random.rand(N))**2  # size

plt.scatter(x, y)
plt.show()
